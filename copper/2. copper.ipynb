# %%
import pandas as pd
df = pd.read_csv('C:/Users/sunAr/Documents/sunArise/quant/commodity/market_data_2005_2025.csv')
df.head()
# Out:
#      datetime ticker        Open        High         Low       Close  \
# 0  2005-01-03    SPY  121.559998  121.760002  119.900002  120.300003
# 1  2005-01-04    SPY  120.459999  120.540001  118.440002  118.830002
# 2  2005-01-05    SPY  118.739998  119.250000  118.000000  118.010002
# 3  2005-01-06    SPY  118.440002  119.150002  118.260002  118.610001
# 4  2005-01-07    SPY  118.970001  119.230003  118.129997  118.440002
#
#    Adj Close      Volume
# 0  81.847137  55748000.0
# 1  80.846962  69167600.0
# 2  80.289108  65667300.0
# 3  80.697319  47814700.0
# 4  80.581635  55847700.0
